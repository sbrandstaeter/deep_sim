# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import pcolor
import matplotlib.cm as cm

# %%
ele = 64
xlist = np.linspace(-3.0, 3.0, ele)
ylist = np.linspace(-3.0, 3.0, ele)
X, Y = np.meshgrid(xlist, ylist)
Z = np.random.randint(2,size=ele*ele).reshape(ele,ele)

# %%
fig = plt.figure(figsize=(6,5))
left, bottom, width, height = 0.1, 0.1, 0.8, 0.8
ax = fig.add_axes([left, bottom, width, height]) 

cmap = cm.get_cmap('jet') # brg hsv jet
cp = ax.contourf(X, Y, Z, 1, cmap = cmap)
fig.colorbar(cp) # Add a colorbar to a plot
ax.set_title('Effective Contact Area Distribution')
plt.show()
