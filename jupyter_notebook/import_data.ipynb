# %%
import numpy as np

# %%
# %ls
# Out:
# import_data.ipynb  result_force_surface_0.dat

# %%
np.genfromtxt("result_force_surface_0.dat", delimiter=';', dtype=None, names =True)
# Out:
# array([(5738.16,    0.   ,    0.  , 0,    0.  , False),
#        (   0.  , 3012.61 , 1187.03, 0, 5397.64, False),
#        (   0.  , 2970.78 ,    0.  , 0,    0.  , False),
#        (   0.  ,  315.293, 4677.41, 0,    0.  , False)],
#       dtype=[('0', '<f8'), ('0_1', '<f8'), ('0_2', '<f8'), ('0_3', '<i8'), ('0_4', '<f8'), ('f0', '?')])

# %%
# Using readlines()
file1 = open(file_name, 'r')
Lines = file1.readlines()
 
count = 0
# Strips the newline character
for line in Lines:
    for i in line.split(';'):
        print(i)
        if i == "0":
            count += 1
count
# Out:
# 0
# 0
# 0
# 0
# 0
#
#
# 5738.16
# 0
# 0
# 0
# 0
#
#
# 0
# 3012.61
# 1187.03
# 0
# 5397.64
#
#
# 0
# 2970.78
# 0
# 0
# 0
#
#
# 0
# 315.293
# 4677.41
# 0
# 0
# 18

# %%
H = 1
area = 5
with open(file_name, "a") as myfile:
    myfile.write(str(H) + "," +str(area) + "\n")

myfile.close()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %matplotlib inline

# %%
df = pd.read_csv("contact_area.dat", header=None)

# %%
plt.scatter(df[0],df[1])

# %%
df[1,]
# Out:
# 0     44.0
# 1     32.0
# 2     32.0
# 3     64.0
# 4     60.0
#       ...
# 95    48.0
# 96    36.0
# 97    28.0
# 98    72.0
# 99    36.0
# Name: 1, Length: 100, dtype: float64
